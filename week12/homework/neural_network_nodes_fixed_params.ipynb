# %%
import os
os.chdir(r'C:\Users\nadda\Desktop\KU\01204314-65-Statistics-for-Computer-Engineering-Applications\week12\homework')
os.getcwd()
# Out:
# 'C:\\Users\\nadda\\Desktop\\KU\\01204314-65-Statistics-for-Computer-Engineering-Applications\\week12\\homework'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import scatter_matrix
# %matplotlib inline

# %%
orig_df = pd.read_csv('meat_diary_oils_seafood_fruits_nuts.csv')
fig_folder = ''
orig_df.head(10)
# Out:
#        Food Name Category Name  Calcium  Calories  Carbs  Cholesterol  \
# 0        Acerola        Fruits    0.012      32.0    7.7          0.0
# 1          Apple        Fruits    0.006      52.0   14.0          0.0
# 2        Apricot        Fruits    0.013      48.0   11.0          0.0
# 3    Dried fruit        Fruits    0.055     241.0   63.0          0.0
# 4        Avocado        Fruits    0.012     160.0    8.5          0.0
# 5         Banana        Fruits    0.005      89.0   23.0          0.0
# 6     Blackberry        Fruits    0.029      43.0    9.6          0.0
# 7      Blueberry        Fruits    0.006      57.0   14.0          0.0
# 8  Boysenberries        Fruits    0.027      50.0   12.0          0.0
# 9     Breadfruit        Fruits    0.017     103.0   27.0          0.0
#
#     Copper   Fats  Fiber    Folate  ...  Vitamin A RAE  Vitamin B1  \
# 0  0.00009   0.30    1.1  0.000014  ...       0.000038     0.00002
# ...

# %%
orig_df.shape
# Out:
# (411, 32)

# %%
sns.heatmap(orig_df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()

# %%
null_percent = orig_df.isnull().sum()/len(orig_df)*100
null_percent
# Out:
# Food Name               0.000000
# Category Name           0.000000
# Calcium                 0.486618
# Calories                0.000000
# Carbs                   0.000000
# Cholesterol             4.622871
# Copper                  4.866180
# Fats                    0.000000
# Fiber                   7.055961
# Folate                  6.569343
# Iron                    0.243309
# Magnesium               2.676399
# Monounsaturated Fat     9.489051
# Net carbs               0.000000
# Phosphorus              1.216545
# Polyunsaturated fat     9.489051
# Potassium               2.189781
# Protein                 0.000000
# Saturated Fat           8.759124
# Selenium               10.948905
# Sodium                  1.459854
# Vitamin A (IU)          1.946472
# Vitamin A RAE           4.136253
# Vitamin B1              1.946472
# Vitamin B12             4.866180
# Vitamin B2              1.703163
# Vitamin B3              1.946472
# Vitamin B5             12.408759
# ...

# %%
cleaned_df = orig_df.copy()

# %%
cleaned_df = cleaned_df.dropna()
cleaned_df.shape
# Out:
# (298, 32)

# %%
null_percent = cleaned_df.isnull().sum()/len(cleaned_df)*100
null_percent
# Out:
# Food Name              0.0
# Category Name          0.0
# Calcium                0.0
# Calories               0.0
# Carbs                  0.0
# Cholesterol            0.0
# Copper                 0.0
# Fats                   0.0
# Fiber                  0.0
# Folate                 0.0
# Iron                   0.0
# Magnesium              0.0
# Monounsaturated Fat    0.0
# Net carbs              0.0
# Phosphorus             0.0
# Polyunsaturated fat    0.0
# Potassium              0.0
# Protein                0.0
# Saturated Fat          0.0
# Selenium               0.0
# Sodium                 0.0
# Vitamin A (IU)         0.0
# Vitamin A RAE          0.0
# Vitamin B1             0.0
# Vitamin B12            0.0
# Vitamin B2             0.0
# Vitamin B3             0.0
# Vitamin B5             0.0
# Vitamin B6             0.0
# Vitamin C              0.0
# Zinc                   0.0
# Manganese              0.0
# dtype: float64

# %%
cleaned_df.dtypes
# Out:
# Food Name               object
# Category Name           object
# Calcium                float64
# Calories               float64
# Carbs                  float64
# Cholesterol            float64
# Copper                 float64
# Fats                   float64
# Fiber                  float64
# Folate                 float64
# Iron                   float64
# Magnesium              float64
# Monounsaturated Fat    float64
# Net carbs              float64
# Phosphorus             float64
# Polyunsaturated fat    float64
# Potassium              float64
# Protein                float64
# Saturated Fat          float64
# Selenium               float64
# Sodium                 float64
# Vitamin A (IU)         float64
# Vitamin A RAE          float64
# Vitamin B1             float64
# Vitamin B12            float64
# Vitamin B2             float64
# Vitamin B3             float64
# Vitamin B5             float64
# Vitamin B6             float64
# Vitamin C              float64
# ...

# %%
cleaned_df.columns
# Out:
# Index(['Food Name', 'Category Name', 'Calcium', 'Calories', 'Carbs',
#        'Cholesterol', 'Copper', 'Fats', 'Fiber', 'Folate', 'Iron', 'Magnesium',
#        'Monounsaturated Fat', 'Net carbs', 'Phosphorus', 'Polyunsaturated fat',
#        'Potassium', 'Protein', 'Saturated Fat', 'Selenium', 'Sodium',
#        'Vitamin A (IU)', 'Vitamin A RAE', 'Vitamin B1', 'Vitamin B12',
#        'Vitamin B2', 'Vitamin B3', 'Vitamin B5', 'Vitamin B6', 'Vitamin C',
#        'Zinc', 'Manganese'],
#       dtype='object')

# %%
cleaned_df.describe()
# Out:
#           Calcium    Calories       Carbs  Cholesterol      Copper  \
# count  298.000000  298.000000  298.000000   298.000000  298.000000
# mean     0.096695  240.244966    7.583960     0.083275    0.000261
# std      0.195170  194.588707   12.580835     0.141691    0.000928
# min      0.000000   11.000000    0.000000     0.000000    0.000000
# 25%      0.012000  109.000000    0.000000     0.000000    0.000040
# 50%      0.025000  188.000000    1.900000     0.066000    0.000080
# 75%      0.080750  310.500000   11.000000     0.092750    0.000160
# max      1.109000  902.000000   79.000000     1.085000    0.014000
#
#              Fats       Fiber      Folate        Iron   Magnesium  ...  \
# count  298.000000  298.000000  298.000000  298.000000  298.000000  ...
# mean    16.964933    1.075168    0.000023    0.001656    0.034279  ...
# std     22.467859    2.290366    0.000048    0.002349    0.049395  ...
# min      0.010000    0.000000    0.000000    0.000000    0.000000  ...
# ...

# %% [markdown]
# ### Set Up Data

# %%
df = cleaned_df.copy()

# %%
# Create list of input attributes and output variable
df = cleaned_df.copy()
output_var = 'Calories'
input_vars = df.columns.tolist()
input_vars.remove('Food Name')
input_vars.remove('Category Name')
input_vars.remove('Calories')
# Create attribute input and output datasets
X = df[input_vars]
y = df[output_var]

# %%
import statsmodels.api as sm
X = sm.add_constant(X, prepend=False)

# %%
# Change number of parameters here
num_params = 10

# %% [markdown]
# ### For a specific groundtruth y, Create (1) Distribution of f_hat, and find (2) a Value of E(f_hat)

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
test_percent = 0.2
main_X_train, X_test, main_y_train, y_test = train_test_split(X, y, test_size=test_percent) 

from sklearn.preprocessing import StandardScaler
scaled_main_X_train = StandardScaler().fit_transform(main_X_train)
scaled_X_test = StandardScaler().fit_transform(X_test)

num_iterations = 200     # can choose other  values

selected_percent = [0.1, 0.2, 0.3]   # can choose other  values
selected_train_size = [int(len(main_X_train)*percent) for percent in selected_percent]
print(selected_train_size)
test_size = len(X_test)

test_f_hat = np.zeros((len(selected_train_size), num_iterations))  

# select the first value in y_test to be ground truth (can select any value in y_test)
ground_truth_y = y_test.tolist()[0]  
print(ground_truth_y)

for t in range(len(selected_train_size)):
    train_size = selected_train_size[t]
    for i in range(num_iterations):                 
        rand_index = np.random.permutation(len(main_X_train))[:train_size]
        idx = main_y_train.index[rand_index]
        scaled_X_train, y_train = scaled_main_X_train[rand_index.tolist()], main_y_train.loc[idx]

        param_X_train = scaled_X_train[:,0:num_params]
        param_X_test = scaled_X_test[:,0:num_params]
        
        fixed_num_nodes = 5
        num_layers = 2
        hidden_layer_info = [fixed_num_nodes for j in range(num_layers)]
        hidden_layer_info = tuple(hidden_layer_info)
        lm=MLPRegressor(hidden_layer_sizes=hidden_layer_info,activation='relu')
        lm.fit(param_X_train, y_train)
        test_param_y_predicted = lm.predict(param_X_test)
        test_f_hat[t,i] = test_param_y_predicted[0]  # prediction of ground truth y

# test_f_hat dimension = len(selected_train_size) x num_iterations
# np.mean(W,d) = average W in d dimension, where d = 0 = first dimension 
test_E_f_hat = np.mean(test_f_hat, 1)  # average over 2nd dimension or num_iterations
                                       # test_E_f_hat dimension = len(selected_train_size)
print(test_E_f_hat)
# Out:
# [23, 47, 71]
# 102.0
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# Plot distribution of f_hat for 3 parameters, along with E_f_hat and ground_truth_y
max_heights = [0.005, 0.15, 0.15]   # can choose other  values
colors = np.array(['tab:green', 'tab:purple', 'tab:orange'])

fig, axs = plt.subplots(len(selected_train_size), figsize=(12, 6))
for k in range(len(selected_train_size)):    
    # plot distribution of f_hat
    axs[k].hist(test_f_hat[k], density=True, color=colors[k], alpha=0.6, label=r'$\hat{f}$')   
    
    #plot E_f_hat
    axs[k].plot([test_E_f_hat[k], test_E_f_hat[k]], [0, max_heights[k]], c='k', linewidth=2.0, label=r'$\mathbb{E}[\hat{f}]$')

    # plot ground_truth_y
    axs[k].plot([ground_truth_y, ground_truth_y], [0, max_heights[k]], 'r', linewidth=2.0, label=r'$ground\_truth\_y$')

    # set title and legend
    axs[k].title.set_text('#Parameters = {0}, Train Percent = {1:.0f}%'.format(num_params, selected_percent[k]*100))
    axs[k].legend(fontsize=12)
    
plt.show()

# %% [markdown]
# ### Bias-Variance Tradeoff

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
test_percent = 0.2
main_X_train, X_test, main_y_train, y_test = train_test_split(X, y, test_size=test_percent) 

from sklearn.preprocessing import StandardScaler
scaled_main_X_train = StandardScaler().fit_transform(main_X_train)
scaled_X_test = StandardScaler().fit_transform(X_test)

num_iterations = 200     # can choose other  values

interval = 0.05       # can choose other  values
start_percent = 0.2   # can choose other  values
end_percent = 1       # can choose other  values 
train_percent_list = np.arange(start_percent, end_percent, interval)
train_size_list = [int(len(main_X_train)*percent) for percent in train_percent_list]
print(train_size_list)

test_size = len(X_test)
print(test_size)

train_squared_error = np.zeros((len(train_size_list), num_iterations))  # shape: Percents x Iterations
test_f_hat = np.zeros((len(train_size_list), num_iterations, test_size))  # shape: Percents x Iterations x Test_size

for t in range(len(train_size_list)):
    train_size = train_size_list[t]
    
    for i in range(num_iterations):
        # Shuffle and select training set with specific train_size
        rand_index = np.random.permutation(len(main_X_train))[:train_size]  
        idx = main_y_train.index[rand_index]
        scaled_X_train, y_train = scaled_main_X_train[rand_index.tolist()], main_y_train.loc[idx]
    
        # Get the leftmost num_params columns to be inputs of linear model
        param_X_train = scaled_X_train[:,0:num_params]
        param_X_test = scaled_X_test[:,0:num_params]

        # Derive the model with the specified inputs
        fixed_num_nodes = 5
        num_layers = 2
        hidden_layer_info = [fixed_num_nodes for j in range(num_layers)]
        hidden_layer_info = tuple(hidden_layer_info)
        lm=MLPRegressor(hidden_layer_sizes=hidden_layer_info,activation='relu')
        lm.fit(param_X_train, y_train)

        # Make predictions for training and test sets
        train_param_y_predicted = lm.predict(param_X_train)
        test_param_y_predicted = lm.predict(param_X_test)

        # Compute MSE for all samples in training set
        train_squared_error[t, i] = np.mean((y_train.tolist() - train_param_y_predicted) ** 2) # shape: Percents x Iterations

        # Collect predictions of test sets to compute MSE for test sets later
        test_f_hat[t, i, :] = test_param_y_predicted  # shape: Percents x Iterations x Test_size

print('Done')
# Out:
# [47, 59, 71, 83, 95, 107, 118, 130, 142, 154, 166, 178, 190, 202, 214, 226]
# 60
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\nadda\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
# train_squared_error dimension = # shape: Percents x Iterations
# Get average MSE for all iterations
avg_train_squared_error = np.mean(train_squared_error, 1)  # shape: Percents

# test_f_hat dimension = Percents x Iterations x Test_size
# Get average f_hat = E[f_hat] by avearaing over iterations
test_E_f_hat = np.mean(test_f_hat, 1)   # shape: Percents x Test_size

# test_f_hat dimension = Percents x Iterations x Test_size
# Compute test_squared_error = ||y - f_hat ||^2  for each iteration, for each sample in the test set
test_all_squared_error = (y_test.tolist() - test_f_hat) ** 2  # shape: Percents x Iterations x Test_size
# Averaging test_squared_error for all iterations, for each sample in the test set  
test_sample_squared_error = np.mean(test_all_squared_error, 1)   # shape: Percents x Test_size
# Compute average test_squared_error for all samples in the test set
avg_test_squared_error = np.mean(test_sample_squared_error, 1)    # shape: Percents

# test_E_f_hat dimension = Percents x Test_size
# Compute bias_squared = || y - E[f_hat] ||^2 for each sample in the test set
test_sample_bias_squared = (y_test.tolist() - test_E_f_hat) ** 2   # shape: Percents x Test_size
# Compute average bias_squared for all samples in the test set
avg_test_bias_squared = np.mean(test_sample_bias_squared, 1)  # shape: Percents

# test_f_hat dimension = Percents x Iterations x Test_size
# Compute Var[f_hat] for each sample in the test set
test_sample_var_f_hat = np.var(test_f_hat, 1)   # shape: Percents x Test_size
# Compute average bias_squared for all samples in the test set
avg_test_var_f_hat = np.mean(test_sample_var_f_hat, 1)  # shape: Percents

print(avg_train_squared_error)
print(avg_test_squared_error)
print(avg_test_bias_squared)
print(avg_test_var_f_hat)
# Out:
# [96235.07065688 97639.52623738 95347.39334064 96433.95608793
#  94686.92450771 96482.67671779 96050.48971149 94992.87046608
#  95766.93012061 95842.3430396  96218.34300789 95206.8468121
#  95486.60717902 94469.99598753 90670.24186481 90097.04942274]
# [84916.93379303 84641.83710735 84863.05108069 84890.93875018
#  84787.74105794 84840.85306135 84750.02172034 84629.32940661
#  84946.93744195 84764.614722   84793.92142239 84717.90722514
#  84899.35524612 83504.84425667 80084.55605701 79450.65090491]
# [84908.85772286 84630.62427439 84854.31334778 84882.48847
#  84777.91558673 84831.4305152  84739.39184926 84619.79062936
#  84937.76546892 84756.03692266 84784.63928592 84708.07986924
#  84889.44527646 83479.6727911  79995.94680278 79352.28108911]
# [ 8.07607017 11.21283296  8.73773291  8.45028019  9.82547121  9.42254614
#  10.62987108  9.53877725  9.17197303  8.57779934  9.28213647  9.8273559
#   9.90996966 25.17146558 88.60925423 98.3698158 ]

# %%
# Plot bias-variance 
x_list = [percent*100 for percent in train_percent_list]
xtick_labels = ['{0:.0f}'.format(percent*100) for percent in train_percent_list]

fig, ax = plt.subplots(3,1)
ax[0].plot(x_list, avg_test_bias_squared, 'y-.', label=r'bias squared: $(\mathbb{E}[\hat{f}] - y)^2$')  
ax[0].set_xticks(x_list)
ax[0].set_xticklabels(xtick_labels, rotation=60)
ax[0].set_xlabel('Percent of Training Set', size=10)
ax[0].set_ylabel('Squared Error', size=10)
ax[0].legend(fontsize=10)
ax[0].set_title('Number of Parameters = '+str(num_params), fontsize=10)

ax[1].plot(x_list, avg_test_var_f_hat, 'b:', label=r'$var(\hat{f})$')  
ax[1].set_xticks(x_list)
ax[1].set_xticklabels(xtick_labels, rotation=60)
ax[1].set_xlabel('Percent of Training Set', size=10)
ax[1].set_ylabel('Squared Error', size=10)
ax[1].legend(fontsize=10)

ax[2].plot(x_list, avg_test_bias_squared, 'y-.', label=r'bias squared: $(\mathbb{E}[\hat{f}] - y)^2$')  
ax[2].plot(x_list, avg_test_var_f_hat, 'b:', label=r'$var(\hat{f})$')  
ax[2].set_xticks(x_list)
ax[2].set_xticklabels(xtick_labels, rotation=60)
ax[2].set_xlabel('Percent of Training Set', size=10)
ax[2].set_ylabel('Squared Error', size=10)
ax[2].legend(fontsize=10)

plt.show()

# %%
# Plot training and testing errors
x_list = [percent*100 for percent in train_percent_list]
xtick_labels = ['{0:.0f}'.format(percent*100) for percent in train_percent_list]

fig, ax = plt.subplots(3,1)
ax[0].plot(x_list, avg_test_squared_error, 'r', label='test error') 
ax[0].set_xticks(x_list)
ax[0].set_xticklabels(xtick_labels, rotation=60)
ax[0].set_xlabel('Percent of Training Set', size=10)
ax[0].set_ylabel('Squared Error', size=10)
ax[0].legend(fontsize=10)
ax[0].set_title('Number of Parameters = '+str(num_params), fontsize=10)

ax[1].plot(x_list, avg_train_squared_error, 'g--', label='training error') 
ax[1].set_xticks(x_list)
ax[1].set_xticklabels(xtick_labels, rotation=60)
ax[1].set_xlabel('Percent of Training Set', size=10)
ax[1].set_ylabel('Squared Error', size=10)
ax[1].legend(fontsize=10)

ax[2].plot(x_list, avg_test_squared_error, 'r', label='test error') 
ax[2].plot(x_list, avg_train_squared_error, 'g--', label='training error') 
ax[2].set_xticks(x_list)
ax[2].set_xticklabels(xtick_labels, rotation=60)
ax[2].set_xlabel('Percent of Training Set', size=10)
ax[2].set_ylabel('Squared Error', size=10)
ax[2].legend(fontsize=10)

plt.show()

# %%
# Plot everything
x_list = [percent*100 for percent in train_percent_list]
xtick_labels = ['{0:.0f}'.format(percent*100) for percent in train_percent_list]

fig, ax = plt.subplots()
ax.plot(x_list, avg_test_squared_error, 'r', label='test error') 
ax.plot(x_list, avg_train_squared_error, 'g--', label='training error') 

ax.plot(x_list, avg_test_bias_squared, 'y-.', label=r'bias squared: $(\mathbb{E}[\hat{f}] - y)^2$')  
ax.plot(x_list, avg_test_var_f_hat, 'b:', label=r'$var(\hat{f})$')  

ax.set_xticks(x_list)
ax.set_xticklabels(xtick_labels, rotation=60)
ax.set_xlabel('Number of Parameters', size=10)
ax.set_ylabel('Squared Error', size=10)
ax.legend(loc='upper right', fontsize=10)
ax.set_title('Number of Parameters = '+str(num_params), fontsize=10)

fig.savefig(fig_folder+'bv_mseloss_param_'+str(num_params)+'.jpg')
plt.show()
